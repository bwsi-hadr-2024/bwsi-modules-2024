# %% [markdown]
# # Intro to Deep Learning
# We're going to continue working with CAP imagery for the second half of this week. Recall the two main guiding questions for this week:
# - _What_ is in an image (e.g. debris, buildings, etc.)?
# - _Where_ are these things located _in 3D space_ ?
#
# ## Motivation
#
# We've already seen how structure from motion can begin to answer the second of those questions, at least in a coarse manner. The first question is more difficult than the second for one crucial reason: it (so far) can not be answered *solely* using image data. Recall that structure from motion was able to leverage image metadata, features and geometric constraints without having to insert any "outside" data. When detecting the components of an image, there is a certain amount of subjectivity that so far requires human input. For example, if you want to detect flooding in an image, there need to be some set of rules that the software can determine "if (rules are satisfied), then (flooding = True)".
#
# How can you start to tackle this problem? We're going to make the problem a bit simpler by turning it into a classification problem rather than a localization problem. That is, instead of finding where flooding is in an image, we'll find whether there is flooding at all. With that in mind, let's first try a naive approach and see if we can simply enumerate the rules. Let's look at some flooding images:
#
# <img src="notebook_images/010_1282_99809b0c-fc64-46e5-957f-7ff8e7547d8c.jpg" width="500"  />
#
# <img src="notebook_images/DSC_0655_0cbbe7e5-be24-4274-bf5a-664c6f2dc3e1.jpg" width="500"  />
#
# So what do we see? It looks like flooding is this murky, brown color that covers most of the image. So let's make a rule: if some percentage of the image is this brownish color (you can think of detecting this by creating some sort of index, like you did with the satellite imagery), there is flooding in the image. This might work for the two images we saw, but the real test is seeing if it works with other images. So let's look at another one:
#
# <img src="notebook_images/DSC_8218_7bb15c80-481b-411a-a54a-a36e9d8b6098.jpg" width="500"  />
#
# This image has a large percentage of it covered by brownish looking water. However, it's clearly not flooding, but rather just a lake. No problem, let's just make another rule: if some percentage of the image is this brownish color *and* there are also lots of buildings (let's also make an index for that), there is flooding in the image. Let's see if this works:
#
# <img src="notebook_images/DSC_8192_fe6812cd-c985-4e59-a62c-04a883ec42cc.jpg" width="500"  />
#
# Again, this is just some lake (the same lake as before, in fact). At this point, we might be thinking of shifting our strategy a bit. Clearly having someone sit down and enumerate all of the rules is impractical in this case\*. There is simply too much variability in the images to come up with a set of rules that is remotely generalizable.
#
# This is one of the major motivations of machine learning. The idea is that, rather than enumerate the rules that determine flooding, we're going to just enumerate the outcomes (e.g. whether there is flooding or not) and develop algorithms for the computer to *learn* what the rules are. There is a rich literature (and a host of undergraduate and graduate courses) on how these algorithms are designed, but on these next couple of days we will instead focus on how to interpret and implement them.
#
# \* This isn't to say that enumerating the rules isn't practical in *every* case. It really depends on the characteristics of the data.

# %% [markdown]
# ## A simple case study
#
# We're going to start with a simple dataset. We will use the  Breast Cancer Wisconsin (Diagnostic) Data Set (https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+(Diagnostic)), a dataset that shows whether a tumor is benign or malign and various other features.

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.datasets import load_breast_cancer
import re # regular expressions, part of standard python library

# read the dataframe
df = load_breast_cancer(return_X_y=False, as_frame=True)["data"]
df["target"] = load_breast_cancer(return_X_y=False, as_frame=True)["target"] # benign is 1, malign is 0
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                   0.07871  ...          17.33           184.60      2019.0
# 1                   0.05667  ...          23.41           158.80      1956.0
# 2                   0.05999  ...          25.53           152.50      1709.0
# 3                   0.09744  ...          26.50            98.87       567.7
# 4                   0.05883  ...          16.67           152.20      1575.0
# ..                      ...  ...            ...              ...         ...
# 564                 0.05623  ...          26.40           166.10      2027.0
# 565                 0.05533  ...          38.25           155.00      1731.0
# 566                 0.05648  ...          34.12           126.70      1124.0
# 567                 0.07016  ...          39.42           184.60      1821.0
# 568                 0.05884  ...          30.37            59.16       268.6
#
#      worst smoothness  worst compactness  worst concavity  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      worst concave points  worst symmetry  worst fractal dimension  target
# 0                  0.2654          0.4601                  0.11890       0
# 1                  0.1860          0.2750                  0.08902       0
# 2                  0.2430          0.3613                  0.08758       0
# 3                  0.2575          0.6638                  0.17300       0
# 4                  0.1625          0.2364                  0.07678       0
# ..                    ...             ...                      ...     ...
# 564                0.2216          0.2060                  0.07115       0
# 565                0.1628          0.2572                  0.06637       0
# 566                0.1418          0.2218                  0.07820       0
# 567                0.2650          0.4087                  0.12400       0
# 568                0.0000          0.2871                  0.07039       1
#
# [569 rows x 31 columns]

# %%
# for now we're just going to focus on mean radius and mean texture.
# we'll plot one against the other, and color code depending on survival
df_b = df[df["target"] == 1]
df_m = df[df["target"] == 0]

# plotting
plt.plot(df_b["mean radius"], df_b["mean texture"], "ro")
plt.plot(df_m["mean radius"], df_m["mean texture"], "bo")
plt.xlabel("mean radius")
plt.ylabel("mean texture")
plt.show()

# %% [markdown]
# So what do we see? Clearly there are factors beyond the ones plotted that explain whether a tumor is benign. However, it's not difficult to see a pattern here. The further up and to the right you are, the less likely you are to survive. So as a first attempt, we will have the software learn a *linear classifier*. This classifier will be a line that will classify you as benign if you are below the line, and malign otherwise.

# %%
from sklearn import svm
from sklearn.model_selection import train_test_split
try:
    from mlxtend.plotting import plot_decision_regions
except:
    # !pip install mlxtend
    from mlxtend.plotting import plot_decision_regions

# setting the features and the targets
X = df[["mean radius", "mean texture"]]
y = df["target"]

# splitting training and testing set 80/20
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Initialize SVM classifier
classifier = svm.SVC(kernel='linear')

# Fit data
classifier = classifier.fit(X_train, y_train)

# Printing parameters
coef = classifier.coef_
print(coef)

# Plot decision boundary
plot_decision_regions(X_train.values, y_train.values.astype(np.integer), clf=classifier, legend=2)
plt.xlabel("mean radius")
plt.ylabel("mean texture")
plt.show()

# %% [markdown]
# There is a lot going on here, so let's try to break it down. Recall that we are trying to determine whether a patient survives using just the (normalized) age and detected nodes. These are called the explanatory variables or *features*, and we refer to it as $X$. The variable we are trying to predict is the prediction variable or *target*, and we refer to it as $y$.
#
# The underlying notion behind machine learning is that patterns that hold in a subset of data will hold in the population as a whole. So in a sense, we care about the performance of the classifier on data that the algorithm has *not* seen by learning patterns in that data that we have seen. To this end, one of the major paradigms in machine learning is to separate our data into a *training set* and a *testing set*. The training set is a subset of the given data that we will actually provide to the algorithm to learn, while the testing set will be used solely to report the performance on data that the algorithm has not seen. In our case, we set 80% of the data as training data and 20% as testing data.
#
# There are numerous algorithms that can train on data. One of the more popular ones (especially before neural networks were introduced) are called *support vector machines* (SVM). We will not discuss how it actually does the learning, but suffice to say it takes in the training data and finds the line that minimizes the classification error. This line is called the *decision boundary* and it is defined by the following equation:
#
# \begin{equation}
# C_1(mean\ radius) + C_2(mean\ texture) = 0
# \end{equation}
#
# Where $C_1$ and $C_2$ are the coefficients of the linear classifier. So really, the function of the SVM is to find these two coefficients. The algorithm then does classification as follows:
#
# \begin{equation}
# y_{pred} =
# \begin{cases}
#     1               & \text{if } C_1(mean\ radius) + C_2(mean\ texture)\geq 0\\
#     0,              & \text{otherwise}
# \end{cases}
# \end{equation}
#
# ### Exercise
# - Look at the first 5 samples in the testing data set. Calculate the predicted target of each of the 5 samples?
# - Look at the corresponding targets. Are the predictions accurate? What proportion of the predicted values are correctly predicted?
# - Which of the two coefficients is most important? Why?

# %% [markdown]
# How good is our classifier? We can look at the performance of our classifier on the testing set to find out. Of course, an important metric to look out for is the accuracy:
#
# \begin{equation}
# \text{Accuracy} = \frac{\#\ (y_{true} == y_{pred})}{\# \ \text{samples}}
# \end{equation}
#
# However, for most applications it is also worth understanding what your *false positive* and *false negative* rate is. A false positive is a sample that is classified as a 1 but is in reality a 0, and a false negative is the opposite\*. The false positive rate is defined as $\frac{\# \text{False positives}}{\# \ \text{False positives + True negatives}}$, while the false negative rate is defined as $\frac{\# \text{False negatives}}{\# \ \text{False negatives + True positives}}$. **Why would this be a metric we care about, especially in this case?**
#
# <details>
#     <summary>ANSWER</summary>
#     Imagine your tumor is predicted as malignant but is in fact benign. There is certainly now a cost you incur in further tests or surgeries, but ultimately it is a manageable cost. Now imagine if you predicted a tumor as benign even thoguh it is malignant. Here, the mistake of the classifier could certainly cost you your life.
# </details>
#
# It turns out there is a useful tool called a *confusion matrix* that handily lays it out for you.
#
# \* It's worth putting some effort into what we call positives and negatives. Here, we use the term positive to mean 1 (benign) and negative to mean 0 (malign). However, anyone that has had a test of any sort knows that positive usually means that you have the disease (in our case, malign tumor). A lot of data science is communicating results, so something worth thinking about.

# %%
from sklearn.metrics import plot_confusion_matrix

predictions = classifier.predict(X_test)
accuracy = np.sum(predictions == y_test)/np.size(predictions)
print(accuracy)

matrix = plot_confusion_matrix(classifier, X_test, y_test,
                                 cmap=plt.cm.Blues,
                                 normalize='true')
plt.title('Confusion matrix for our classifier')
plt.show(matrix)
plt.show()

# %% [markdown]
# As a final note, we used two variables (radius and texture) because it made it possible to visualize. However, there is nothing preventing us from using the rest of the data set columns as part of our features. While visualization in more than 2D is much more difficult, the underlying principles are exactly the same.
#
# ### Exercise
# Explore this link which contains a number of classification datasets: https://archive.ics.uci.edu/ml/datasets.php?format=&task=cla&att=&area=&numAtt=&numIns=&type=&sort=nameUp&view=table. Using an SVM, attempt to predict the class of each sample. Consider the following:
# - While multiclass classification is possible, limit yourself thus far to datasets that have one class. Make sure that y is set up with two distinct numbers for the classes (e.g. 0 and 1)
# - Make sure that your dataset does not have missing values. If it does, handle them appropriately (e.g. by substituting it with 0 or with the mean of the column).
#
# How does your classifier perform? Report the accuracy and confusion matrix. What could be done to improve the performance?

# %% [markdown]
# ## Deep learning
# So far, we've worked exclusively with linear decision boundaries. However, usually data is much more complicated (as you should have seen from the exercise). Therefore, we might want to look for something that has higher predictive power. One of the most popular tools in machine learning has been the *neural network*. A neural network is (loosely) inspired by the way neurons are connected and operate. Let's first look at the simplest possible neural network and work our way up:
#
# <img src="notebook_images/nn_nohidden_new.png" width="500"  />
#
# Neural networks are made up of *layers*. In the image above, the neural network has two layers. The first layer is called the *input layer*, and the last layer is called the *output layer*. Each layer is composed of *neurons*. In the input layer, each neuron is one of the features from the training data. For example, the first neuron might be the mean radius, and the second neuron might be the mean texture. We're going to refer to each neuron by $x_{l, n}$, where $l$ is the number of the layer and $n$ is the number of the neuron within the layer. Using this notation, mean radius = $x_{1, 1}$.
#
# Each neuron in the input layer is connected to *every* neuron in the following layer by a *weight*. We will denote each weight by $w_{l, i, o}$, where $l$ is the layer at the tail of the arrow, $i$ is the number of the neuron at the tail of the arrow and $o$ is the number of the neuron at the head of the arrow. In the figure above, the color of the arrow corresponds to the value of the weight (blue means negative, red means positive). Every neuron in subsequent layers is equal to the sum of the products of the neurons and the weight that connects them. In this case, the neuron in the output layer is defined as:
#
# \begin{equation}
# x_{2, 1} = x_{1, 1}w_{1, 1, 1} + x_{1, 2}w_{1, 2, 1}
# \end{equation}
#
# Once you have the value of the output layer, you can obtain the predicted classification by applying some function to $x_{2, 1}$. An example of such a function would be similar to what we did previously:
#
# \begin{equation}
# y_{pred} =
# \begin{cases}
#     1               & \text{if } x_{2, 1}\geq 0\\
#     0,              & \text{otherwise}
# \end{cases}
# \end{equation}
#
# So training a neural network is simply finding the weights $w$ that minimize the error. If you are keen-eyed though, you might have realized that the example above is identical to what we were doing before. Therefore, we still have not arrived at a more powerful classifier. Let's try a more complicated neural network.
#
# <img src="notebook_images/nn_hidden_new.png" width="500"  />
#
# This network is similar to the previous one, but now we have an additional layer in between the input and output layers. All layers that are between input and output are called *hidden layers*, though functionally they behave in exactly the same way. As a quick concept question, **what is the value of $x_{2, 3}$? What about $x_{3, 1}$?**
#
# <details>
#     <summary>ANSWER</summary>
#     $x_{2, 3} = x_{1, 1}w_{1, 1, 3} + x_{1, 2}w_{1, 2, 3}$ ,
#     $x_{3, 1} = x_{2, 1}w_{2, 1, 1} + x_{2, 2}w_{2, 2, 1} + x_{2, 3}w_{2, 3, 1} + x_{2, 4}w_{2, 4, 1} + x_{2, 5}w_{2, 5, 1}$
# </details>
#
# Why are we introducing a hidden layer? Notice that each of the neurons in the hidden layer are essentially acting as linear classifiers. By having a weighted sum of these neurons in the output layer, we are arriving at a function that, by virtue of being a sum of lines is not itself linear. One of the biggest results in machine learning is that, as you increase the number of neurons in the hidden layer, you can approximate *any* function, meaning that you can always make a more powerful classifier by just adding more neurons. However, usually this is not computationally efficient. Rather, most of the time it makes more sense to introduce more hidden layers as opposed to more neurons, as shown in the image below:
#
# <img src="notebook_images/nn_deep.png" width="500"  />
#
# The added "depth" as a result of more layers is where the "deep" in "deep learning" comes. As computational resources have increased, scientists have increasingly resorted to adding more and more layers to their neural networks.
#
# ### Exercise
# Let's start thinking about the LADI dataset. We want to use deep learning to detect whether there is flooding in the image.
# - Using the paradigm above, what would be the features of the dataset? What are the targets?
# - Propose a way that you would input the features into a neural network?
# - What problems might you run into if you directly put an image into the neural network above?

# %% [markdown]
# ## Convolution
# Convolution is a fairly old technique in image processing. Convolution works by multiplying a matrix (called a *kernel*) with portions of the image and adding up the result. An animation of how this works is shown below. The result of applying different kernels is also shown:
#
# <img src="notebook_images/convolution_anim.gif" width="500"  />
#
# <img src="notebook_images/convolution.png" width="500"  />
#
# As you can see, different kernels can pick up different features depending on the specific coefficients of the kernel. In the late 1980s, scientists first thought to use neural networks to learn the kernel values themselves, which created the foundation for the *convolutional* neural network (CNN). These complement the hidden layers from the previous architecture with new convolutional layers, which perform convolution on the previous layer. In so doing, these networks conserve the relationship between nearby pixels and perform very well in image classification.
#
# <img src="notebook_images/cnn.png" width="500"  />

# %% [markdown]
# ## The LADI dataset
# As we already saw, the LADI dataset contains CAP images as well as crowdsourced labels for a number of different categories. Today we're going to start the multi-day exercise of applying deep learning to the LADI dataset in order to do classification of flooding. This section borrows heavily from the following tutorial: https://github.com/LADI-Dataset/ladi-tutorial
#
# ### Data reading and cleaning
# We first have to go through some work to make sure that we only have the components of the dataset that we want.

# %%
# read the tsv file with the labels
ladi_responses_raw = pd.read_csv("http://ladi.s3-us-west-2.amazonaws.com/Labels/ladi_aggregated_responses_url.tsv",delimiter='\t',header='infer')
ladi_responses_raw
# Out:
#                                                       url  WorkerId  \
# 0       https://ladi.s3-us-west-2.amazonaws.com/Images...         0
# 1       https://ladi.s3-us-west-2.amazonaws.com/Images...         1
# 2       https://ladi.s3-us-west-2.amazonaws.com/Images...         2
# 3       https://ladi.s3-us-west-2.amazonaws.com/Images...        20
# 4       https://ladi.s3-us-west-2.amazonaws.com/Images...         0
# ...                                                   ...       ...
# 289835  https://ladi.s3-us-west-2.amazonaws.com/Images...       488
# 289836  https://ladi.s3-us-west-2.amazonaws.com/Images...       496
# 289837  https://ladi.s3-us-west-2.amazonaws.com/Images...       516
# 289838  https://ladi.s3-us-west-2.amazonaws.com/Images...       539
# 289839  https://ladi.s3-us-west-2.amazonaws.com/Images...       539
#
#                         Answer
# 0       ['damage:flood/water']
# 1       ['damage:flood/water']
# 2       ['damage:flood/water']
# 3       ['damage:flood/water']
# 4       ['damage:flood/water']
# ...                        ...
# 289835         ['damage:none']
# 289836         ['damage:none']
# 289837         ['damage:misc']
# 289838         ['damage:none']
# 289839         ['damage:none']
#
# [289840 rows x 3 columns]

# %%
# remove square brackets, split on comma and explode list into individual rows, then merge back with original to get url and WorkerId
ladi_responses = pd.merge(ladi_responses_raw[['url','WorkerId']], 
                          ladi_responses_raw['Answer'].str.strip('[|]').str.split(',').explode(), 
                          left_index=True, 
                          right_index=True).reset_index(drop=True)
# remove whitespace and the single quote character from either end of string
ladi_responses['Answer'] = ladi_responses['Answer'].str.strip(' ').str.strip('\'')
# add a column to help with aggregation when pivoting
ladi_responses['response_count'] = 1
# get the category of each response
ladi_responses['Category'] = ladi_responses['Answer'].str.split(':').apply(lambda x: x[0])
# drop dupes
ladi_responses = ladi_responses.drop_duplicates(ignore_index=True)
ladi_responses
# Out:
#                                                       url  WorkerId  \
# 0       https://ladi.s3-us-west-2.amazonaws.com/Images...         0
# 1       https://ladi.s3-us-west-2.amazonaws.com/Images...         1
# 2       https://ladi.s3-us-west-2.amazonaws.com/Images...         2
# 3       https://ladi.s3-us-west-2.amazonaws.com/Images...        20
# 4       https://ladi.s3-us-west-2.amazonaws.com/Images...         0
# ...                                                   ...       ...
# 394697  https://ladi.s3-us-west-2.amazonaws.com/Images...       488
# 394698  https://ladi.s3-us-west-2.amazonaws.com/Images...       496
# 394699  https://ladi.s3-us-west-2.amazonaws.com/Images...       516
# 394700  https://ladi.s3-us-west-2.amazonaws.com/Images...       539
# 394701  https://ladi.s3-us-west-2.amazonaws.com/Images...       539
#
#                     Answer  response_count Category
# 0       damage:flood/water               1   damage
# 1       damage:flood/water               1   damage
# 2       damage:flood/water               1   damage
# 3       damage:flood/water               1   damage
# 4       damage:flood/water               1   damage
# ...                    ...             ...      ...
# 394697         damage:none               1   damage
# 394698         damage:none               1   damage
# 394699         damage:misc               1   damage
# 394700         damage:none               1   damage
# 394701         damage:none               1   damage
#
# [394702 rows x 5 columns]

# %%
#figure out the total number of responses in each category
# take one entry for each worker, category, url combination, and then create pivot table from it
category_matrix = ladi_responses.groupby(['WorkerId','Category','url'])\
                                .first()\
                                .reset_index()\
                                .pivot_table(values='response_count', 
                                          index='url', 
                                          columns='Category', 
                                          aggfunc='sum',
                                          fill_value=0)
category_matrix
# Out:
# Category                                            damage  environment  \
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...       6            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...       5            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...       3            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...       3            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...       3            3
# ...                                                    ...          ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...       6            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...       8            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...       3            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...       5            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...       6            0
#
# Category                                            infrastructure  vehicle  \
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0        0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0        0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0        0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0        0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               3        3
# ...                                                            ...      ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0        0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0        0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0        0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0        0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0        0
#
# Category                                            water
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...      0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...      0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...      0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...      0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...      3
# ...                                                   ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...      0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...      0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...      0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...      0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...      0
#
# [40197 rows x 5 columns]

# %%
# Create a matrix with the number of workers who answered given label for given image
# using pivot table; filling in nan values with 0
label_matrix = ladi_responses.pivot_table(values='response_count', 
                                          index='url', 
                                          columns='Answer', 
                                          aggfunc='sum',
                                          fill_value=0)
label_matrix
# Out:
# Answer                                              damage:flood/water  \
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                   2
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                   3
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                   1
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                   2
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                   2
# ...                                                                ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                   3
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                   1
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                   0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                   1
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                   2
#
# Answer                                              damage:landslide  \
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# ...                                                              ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 2
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 2
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 1
#
# Answer                                              damage:misc  damage:none  \
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0            4
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0            2
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0            2
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0            1
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0            1
# ...                                                         ...          ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            3            2
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            1            5
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            1            2
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            1            2
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            1            3
#
# Answer                                              damage:rubble  \
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# ...                                                           ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              2
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              1
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              1
#
# Answer                                              damage:smoke/fire  \
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# ...                                                               ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
#
# Answer                                              damage:washout  \
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# ...                                                            ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               1
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               1
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               1
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               1
#
# Answer                                              environment:dirt  \
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# ...                                                              ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
#
# Answer                                              environment:grass  \
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# ...                                                               ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
#
# Answer                                              environment:lava  ...  \
# url                                                                   ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0  ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0  ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0  ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0  ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0  ...
# ...                                                              ...  ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0  ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0  ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0  ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0  ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0  ...
#
# Answer                                              vehicle:boat  vehicle:car  \
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0            3
# ...                                                          ...          ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0            0
#
# Answer                                              vehicle:none  \
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0
# ...                                                          ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0
#
# Answer                                              vehicle:truck  \
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              1
# ...                                                           ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
#
# Answer                                              water:flooding  \
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               3
# ...                                                            ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
#
# Answer                                              water:lake  water:none  \
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...           0           0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...           0           0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...           0           0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...           0           0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...           0           0
# ...                                                        ...         ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...           0           0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...           0           0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...           0           0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...           0           0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...           0           0
#
# Answer                                              water:ocean  water:puddle  \
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0             0
# ...                                                         ...           ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0             0
#
# Answer                                              water:river
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0
# ...                                                         ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0
#
# [40197 rows x 37 columns]

# %%
# create dataframes with percentage of responses that included that label
cat_frac_dfs = {}
for cat in category_matrix.columns:
    frac_df = pd.DataFrame(index=category_matrix.index)
    for label in label_matrix.columns[label_matrix.columns.str.match(cat)]:
        frac_df[label] = (label_matrix[label]/category_matrix[cat])
    cat_frac_dfs[cat] = frac_df.fillna(0)

# %%
def get_training_examples(cat_frac_dfs, category, label, max_samples=5000):
    '''gets the files for a given category and label where the majority of workers said that the label was present
    use max_samples to limit the number of examples
    '''
    if re.search('none', label):
        sample_df = pd.DataFrame(index=cat_frac_dfs[category].loc[cat_frac_dfs[category][label]>0.5].index)
    else:
        sample_df = pd.DataFrame(index=cat_frac_dfs[category].loc[cat_frac_dfs[category][label]>=0.5].index, data={label:1})
    if len(sample_df) > max_samples:
        sample_df = sample_df.sample(max_samples)
    return sample_df

def convert_url_to_local_path(url):
    '''
    converts the url to the location where we will download
    '''
    return url.lstrip('https://')

# %%
# get positive examples for each label of interest
flood_examples = get_training_examples(cat_frac_dfs, 'damage', 'damage:flood/water', 100)
rubble_examples = get_training_examples(cat_frac_dfs, 'damage', 'damage:rubble', 100)
misc_damage_examples = get_training_examples(cat_frac_dfs, 'damage', 'damage:misc', 100)
no_damage_examples = get_training_examples(cat_frac_dfs, 'damage', 'damage:none', 100)

# %%
# Out:
# 0      ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
# 1      ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
# 2      ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
# 3      ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
# 4      ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
#                              ...
# 392    ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
# 393    ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
# 394    ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
# 395    ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
# 396    ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
# Name: url, Length: 397, dtype: object

# %%
# combine entries entries into single dataframe, group by url, and convert labels to 1-hot vector
damage_df = pd.concat([flood_examples, 
                       rubble_examples,
                       misc_damage_examples,
                       no_damage_examples
                      ]).fillna(0).reset_index().groupby('url').max()
damage_df['local_path'] = damage_df.reset_index()['url'].apply(convert_url_to_local_path).values
damage_df.to_csv('damage_examples.csv')
damage_df
# Out:
#                                                     damage:flood/water  \
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 1.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 1.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 1.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 1.0
# ...                                                                ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0.0
#
#                                                     damage:rubble  \
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0.0
# ...                                                           ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            1.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0.0
#
#                                                     damage:misc  \
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...          0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...          0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...          0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...          0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...          0.0
# ...                                                         ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...          0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...          0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...          0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...          0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...          0.0
#
#                                                                                            local_path
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...  ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...  ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...  ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...  ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...  ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
# ...                                                                                               ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...  ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...  ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...  ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...  ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...  ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
#
# [397 rows x 4 columns]

# %%
# create a csv of all the files we want to download as training data to feed into wget
damage_df.reset_index()['url'].to_csv('urls_to_download.csv', index=False, header=False)

# %%
# Load ladi_images_metadata.csv
metadata_df = pd.read_csv('http://ladi.s3-us-west-2.amazonaws.com/Labels/ladi_images_metadata.csv')
metadata_df
# Out:
#                                             uuid            timestamp  \
# 0       a13fb353cca1f5e8060f95c80deb0c49e9a21f91  2016-01-16 07:34:55
# 1       03e5da2bc5e32cd7d58a164eefce499e2f14e06f  2014-06-24 13:09:20
# 2       c97e83122e14ec5fa5cfa6e2c911e066d8a07f7c  2014-06-24 11:06:27
# 3       c534eb158948b63508eab34a667bf495e129f455  2014-06-24 11:20:03
# 4       1c702459e21e5a7e7fec5eefaab42f5e5124113a  2014-06-24 11:21:07
# ...                                          ...                  ...
# 580746  95fabbdbbb494beab517b5fea25a4e430d8fbcef  2020-01-27 12:01:31
# 580747  4b590e5634dae396db6c838844d7670e5ef9e7f6  2020-01-27 12:00:25
# 580748  bb7f86f1e9ab1a1ab3ea9e13cda998ab6e1bbb6d  2020-01-27 12:02:25
# 580749  c9e5c19cb7cccf181d11b707f1a47b80341710b6  2020-01-27 12:00:45
# 580750  a52da08206e51e3cd3b2cd0b42a3bb7e9623e92c  2020-01-27 12:00:39
#
#           gps_lat    gps_lon  gps_alt  file_size   width  height  \
# 0       29.623744 -95.652153     26.0  3497125.0  4608.0  3456.0
# 1       32.386939 -86.344467    489.0  3518243.0  4608.0  3456.0
# 2             NaN        NaN      NaN  8006650.0  6000.0  4000.0
# 3             NaN        NaN      NaN  8821238.0  6000.0  4000.0
# 4       32.371777 -86.345887    459.0  8385536.0  6000.0  4000.0
# ...           ...        ...      ...        ...     ...     ...
# 580746  18.002950 -66.896370    101.8  3413576.0  4000.0  3000.0
# 580747  18.003440 -66.896118    101.8  3307879.0  4000.0  3000.0
# 580748  18.003280 -66.895955    101.8  3989427.0  4000.0  3000.0
# 580749  18.003355 -66.896257    101.8  3722615.0  4000.0  3000.0
# 580750  18.003379 -66.896208    101.8  3696682.0  4000.0  3000.0
#
#                                                   s3_path  \
# 0       s3://ladi/Images/FEMA_CAP/1012/20118/VIRB0002_...
# 1       s3://ladi/Images/FEMA_CAP/1012/20118/VIRB0820_...
# 2       s3://ladi/Images/FEMA_CAP/1012/20118/_DSC0015_...
# 3       s3://ladi/Images/FEMA_CAP/1012/20118/_DSC0123_...
# 4       s3://ladi/Images/FEMA_CAP/1012/20118/_DSC0126_...
# ...                                                   ...
# 580746  s3://ladi/Images/FEMA_CAP/9173/616637/2020_012...
# 580747  s3://ladi/Images/FEMA_CAP/9173/616637/2020_012...
# 580748  s3://ladi/Images/FEMA_CAP/9173/616637/2020_012...
# 580749  s3://ladi/Images/FEMA_CAP/9173/616637/2020_012...
# 580750  s3://ladi/Images/FEMA_CAP/9173/616637/2020_012...
#
#                                                       url
# 0       https://ladi.s3-us-west-2.amazonaws.com/Images...
# 1       https://ladi.s3-us-west-2.amazonaws.com/Images...
# 2       https://ladi.s3-us-west-2.amazonaws.com/Images...
# 3       https://ladi.s3-us-west-2.amazonaws.com/Images...
# 4       https://ladi.s3-us-west-2.amazonaws.com/Images...
# ...                                                   ...
# 580746  https://ladi.s3-us-west-2.amazonaws.com/Images...
# 580747  https://ladi.s3-us-west-2.amazonaws.com/Images...
# 580748  https://ladi.s3-us-west-2.amazonaws.com/Images...
# 580749  https://ladi.s3-us-west-2.amazonaws.com/Images...
# 580750  https://ladi.s3-us-west-2.amazonaws.com/Images...
#
# [580751 rows x 10 columns]

# %%
#download the examples to folder
# !wget --content-disposition --trust-server-names -i urls_to_download.csv -x
# Out:
# --2022-07-28 12:59:36--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20150/DSC_0012_058051a0-26a8-436a-a23d-8b3e7cb60c3d.jpg
# Resolving ladi.s3-us-west-2.amazonaws.com (ladi.s3-us-west-2.amazonaws.com)... 52.218.185.81
# Connecting to ladi.s3-us-west-2.amazonaws.com (ladi.s3-us-west-2.amazonaws.com)|52.218.185.81|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6383549 (6.1M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20150/DSC_0012_058051a0-26a8-436a-a23d-8b3e7cb60c3d.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.09M  --.-KB/s    in 0.03s
#
# 2022-07-28 12:59:36 (187 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20150/DSC_0012_058051a0-26a8-436a-a23d-8b3e7cb60c3d.jpg’ saved [6383549/6383549]
#
# --2022-07-28 12:59:36--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20166/CAP_1818_34987508-0dad-464d-b004-8b42b19cd981.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 14210680 (14M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20166/CAP_1818_34987508-0dad-464d-b004-8b42b19cd981.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  13.55M  --.-KB/s    in 0.1s
#
# 2022-07-28 12:59:37 (100 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20166/CAP_1818_34987508-0dad-464d-b004-8b42b19cd981.jpg’ saved [14210680/14210680]
#
# --2022-07-28 12:59:37--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20173/16-1-337_54a00b7c-ecc5-40c3-ae4e-555f81033da3.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6496879 (6.2M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20173/16-1-337_54a00b7c-ecc5-40c3-ae4e-555f81033da3.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.20M  --.-KB/s    in 0.05s
#
# 2022-07-28 12:59:37 (122 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20173/16-1-337_54a00b7c-ecc5-40c3-ae4e-555f81033da3.jpg’ saved [6496879/6496879]
#
# --2022-07-28 12:59:37--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20187/DSC_0087_76fafd06-f475-481f-a0a4-c5005f6d190a.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6318582 (6.0M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20187/DSC_0087_76fafd06-f475-481f-a0a4-c5005f6d190a.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.03M  --.-KB/s    in 0.02s
#
# 2022-07-28 12:59:37 (315 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20187/DSC_0087_76fafd06-f475-481f-a0a4-c5005f6d190a.jpg’ saved [6318582/6318582]
#
# --2022-07-28 12:59:37--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20195/DSC_0569_0717349c-425c-4868-8057-b3af6983a17f.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6255769 (6.0M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20195/DSC_0569_0717349c-425c-4868-8057-b3af6983a17f.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.97M  27.4MB/s    in 0.2s
#
# 2022-07-28 12:59:37 (27.4 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20195/DSC_0569_0717349c-425c-4868-8057-b3af6983a17f.jpg’ saved [6255769/6255769]
#
# --2022-07-28 12:59:37--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20203/16-1-337_4f24774a-5611-4cf3-a9af-d43525ade1be.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13202835 (13M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20203/16-1-337_4f24774a-5611-4cf3-a9af-d43525ade1be.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  12.59M  59.6MB/s    in 0.2s
#
# 2022-07-28 12:59:37 (59.6 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20203/16-1-337_4f24774a-5611-4cf3-a9af-d43525ade1be.jpg’ saved [13202835/13202835]
#
# --2022-07-28 12:59:37--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20215/CAP_2248_0dc6c90b-6607-4a5c-a1b9-790a0ee469e9.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13164011 (13M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20215/CAP_2248_0dc6c90b-6607-4a5c-a1b9-790a0ee469e9.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  12.55M  70.9MB/s    in 0.2s
#
# 2022-07-28 12:59:38 (70.9 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20215/CAP_2248_0dc6c90b-6607-4a5c-a1b9-790a0ee469e9.jpg’ saved [13164011/13164011]
#
# --2022-07-28 12:59:38--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2024/100502/010_1415_0c25e35d-fc34-405b-ac13-22255070819f.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7985760 (7.6M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2024/100502/010_1415_0c25e35d-fc34-405b-ac13-22255070819f.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   7.62M  --.-KB/s    in 0.05s
#
# 2022-07-28 12:59:38 (140 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2024/100502/010_1415_0c25e35d-fc34-405b-ac13-22255070819f.jpg’ saved [7985760/7985760]
#
# --2022-07-28 12:59:38--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2024/221180/010_2374_27cab62f-305c-43ef-a416-1a2b3f66f28f.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11380597 (11M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2024/221180/010_2374_27cab62f-305c-43ef-a416-1a2b3f66f28f.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  10.85M  60.9MB/s    in 0.2s
#
# 2022-07-28 12:59:38 (60.9 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2024/221180/010_2374_27cab62f-305c-43ef-a416-1a2b3f66f28f.jpg’ saved [11380597/11380597]
#
# --2022-07-28 12:59:38--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2024/221180/010_2596_c85d1f41-a68f-4253-82dc-daa4bce9606f.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11857957 (11M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2024/221180/010_2596_c85d1f41-a68f-4253-82dc-daa4bce9606f.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  11.31M  54.6MB/s    in 0.2s
#
# 2022-07-28 12:59:38 (54.6 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2024/221180/010_2596_c85d1f41-a68f-4253-82dc-daa4bce9606f.jpg’ saved [11857957/11857957]
#
# --2022-07-28 12:59:38--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2024/221180/010_3026_c72d682c-2b01-4537-b4f5-5807a9b0b74a.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 9251954 (8.8M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2024/221180/010_3026_c72d682c-2b01-4537-b4f5-5807a9b0b74a.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   8.82M  --.-KB/s    in 0.09s
#
# 2022-07-28 12:59:39 (97.3 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2024/221180/010_3026_c72d682c-2b01-4537-b4f5-5807a9b0b74a.jpg’ saved [9251954/9251954]
#
# --2022-07-28 12:59:39--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3033/231175/CAPIberv_5eb0c428-1e62-41c5-a820-47df187b4958.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5029622 (4.8M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3033/231175/CAPIberv_5eb0c428-1e62-41c5-a820-47df187b4958.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   4.80M  --.-KB/s    in 0.04s
#
# 2022-07-28 12:59:39 (136 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3033/231175/CAPIberv_5eb0c428-1e62-41c5-a820-47df187b4958.jpg’ saved [5029622/5029622]
#
# --2022-07-28 12:59:39--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291483/DSC_1867_486e26fc-36a0-4046-9700-e8c330b75475.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6856639 (6.5M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291483/DSC_1867_486e26fc-36a0-4046-9700-e8c330b75475.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.54M  --.-KB/s    in 0.04s
#
# 2022-07-28 12:59:39 (174 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291483/DSC_1867_486e26fc-36a0-4046-9700-e8c330b75475.jpg’ saved [6856639/6856639]
#
# --2022-07-28 12:59:39--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291487/Jax-Dela_d52dc02f-0e40-41f0-968c-b19678743744.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10128808 (9.7M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291487/Jax-Dela_d52dc02f-0e40-41f0-968c-b19678743744.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   9.66M  --.-KB/s    in 0.08s
#
# 2022-07-28 12:59:39 (126 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291487/Jax-Dela_d52dc02f-0e40-41f0-968c-b19678743744.jpg’ saved [10128808/10128808]
#
# --2022-07-28 12:59:39--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291499/DSC_0286_c42c9052-2449-46bf-85f3-c7fda2600251.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7230591 (6.9M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291499/DSC_0286_c42c9052-2449-46bf-85f3-c7fda2600251.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.90M  --.-KB/s    in 0.04s
#
# 2022-07-28 12:59:39 (155 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291499/DSC_0286_c42c9052-2449-46bf-85f3-c7fda2600251.jpg’ saved [7230591/7230591]
#
# --2022-07-28 12:59:39--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291499/DSC_0547_1246c32d-1188-46f8-8c01-24dcd6175f13.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7043900 (6.7M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291499/DSC_0547_1246c32d-1188-46f8-8c01-24dcd6175f13.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.72M  --.-KB/s    in 0.03s
#
# 2022-07-28 12:59:39 (197 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291499/DSC_0547_1246c32d-1188-46f8-8c01-24dcd6175f13.jpg’ saved [7043900/7043900]
#
# --2022-07-28 12:59:39--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291501/DSC_0019_15c63970-7a9f-4b70-8024-ae73728b60cd.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6767889 (6.5M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291501/DSC_0019_15c63970-7a9f-4b70-8024-ae73728b60cd.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.45M  --.-KB/s    in 0.07s
#
# 2022-07-28 12:59:40 (97.6 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291501/DSC_0019_15c63970-7a9f-4b70-8024-ae73728b60cd.jpg’ saved [6767889/6767889]
#
# --2022-07-28 12:59:40--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291530/DSC_0777_93efd288-c087-4d18-bc62-e7cb7aa3e73b.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7651108 (7.3M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291530/DSC_0777_93efd288-c087-4d18-bc62-e7cb7aa3e73b.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   7.30M  --.-KB/s    in 0.03s
#
# 2022-07-28 12:59:40 (225 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291530/DSC_0777_93efd288-c087-4d18-bc62-e7cb7aa3e73b.jpg’ saved [7651108/7651108]
#
# --2022-07-28 12:59:40--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291530/DSC_0821_27836b19-4fc5-4347-a47e-433559fe2cc8.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7563329 (7.2M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291530/DSC_0821_27836b19-4fc5-4347-a47e-433559fe2cc8.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   7.21M  --.-KB/s    in 0.05s
#
# 2022-07-28 12:59:40 (146 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291530/DSC_0821_27836b19-4fc5-4347-a47e-433559fe2cc8.jpg’ saved [7563329/7563329]
#
# --2022-07-28 12:59:40--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291530/DSC_1120_c734577a-252d-4773-b3be-21b09039b8e0.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6364324 (6.1M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291530/DSC_1120_c734577a-252d-4773-b3be-21b09039b8e0.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.07M  --.-KB/s    in 0.07s
#
# 2022-07-28 12:59:40 (83.7 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291530/DSC_1120_c734577a-252d-4773-b3be-21b09039b8e0.jpg’ saved [6364324/6364324]
#
# --2022-07-28 12:59:40--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291515/DSC_0130_3fd6ae95-2e89-484d-984d-84a10175763e.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5863019 (5.6M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291515/DSC_0130_3fd6ae95-2e89-484d-984d-84a10175763e.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.59M  --.-KB/s    in 0.02s
#
# 2022-07-28 12:59:40 (275 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291515/DSC_0130_3fd6ae95-2e89-484d-984d-84a10175763e.jpg’ saved [5863019/5863019]
#
# --2022-07-28 12:59:40--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291556/DSC_1924_afeac55c-a4a9-4150-8006-7c349a7ac541.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13512943 (13M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291556/DSC_1924_afeac55c-a4a9-4150-8006-7c349a7ac541.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  12.89M  --.-KB/s    in 0.1s
#
# 2022-07-28 12:59:40 (95.1 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291556/DSC_1924_afeac55c-a4a9-4150-8006-7c349a7ac541.jpg’ saved [13512943/13512943]
#
# --2022-07-28 12:59:40--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291569/DSC_0256_d7e85806-b556-4b8c-b76f-5268b1b681e0.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6855342 (6.5M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291569/DSC_0256_d7e85806-b556-4b8c-b76f-5268b1b681e0.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.54M  --.-KB/s    in 0.02s
#
# 2022-07-28 12:59:41 (295 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291569/DSC_0256_d7e85806-b556-4b8c-b76f-5268b1b681e0.jpg’ saved [6855342/6855342]
#
# --2022-07-28 12:59:41--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291595/DSC_5552_9d4e4a44-2ace-418f-83cb-9c55e026b243.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13513425 (13M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291595/DSC_5552_9d4e4a44-2ace-418f-83cb-9c55e026b243.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  12.89M  60.5MB/s    in 0.2s
#
# 2022-07-28 12:59:41 (60.5 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291595/DSC_5552_9d4e4a44-2ace-418f-83cb-9c55e026b243.jpg’ saved [13513425/13513425]
#
# --2022-07-28 12:59:41--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291620/DSC_0044_ccd37f01-4c72-40f5-a5b9-b1ec58d35626.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5995576 (5.7M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291620/DSC_0044_ccd37f01-4c72-40f5-a5b9-b1ec58d35626.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.72M  --.-KB/s    in 0.02s
#
# 2022-07-28 12:59:41 (357 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291620/DSC_0044_ccd37f01-4c72-40f5-a5b9-b1ec58d35626.jpg’ saved [5995576/5995576]
#
# --2022-07-28 12:59:41--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291621/DSC_1143_30788d3e-8ffd-4aa9-8eab-e2369692db38.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6280558 (6.0M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291621/DSC_1143_30788d3e-8ffd-4aa9-8eab-e2369692db38.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.99M  --.-KB/s    in 0.08s
#
# 2022-07-28 12:59:41 (77.2 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291621/DSC_1143_30788d3e-8ffd-4aa9-8eab-e2369692db38.jpg’ saved [6280558/6280558]
#
# --2022-07-28 12:59:41--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291632/DSC_0254_fe4fa659-426e-4a3a-af8a-dac4cdea11b3.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7069534 (6.7M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291632/DSC_0254_fe4fa659-426e-4a3a-af8a-dac4cdea11b3.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.74M  --.-KB/s    in 0.09s
#
# 2022-07-28 12:59:41 (75.4 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291632/DSC_0254_fe4fa659-426e-4a3a-af8a-dac4cdea11b3.jpg’ saved [7069534/7069534]
#
# --2022-07-28 12:59:41--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291663/DSC_0249_247633f5-55f7-4ce7-9f73-878c919b4104.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6586977 (6.3M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291663/DSC_0249_247633f5-55f7-4ce7-9f73-878c919b4104.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.28M  --.-KB/s    in 0.04s
#
# 2022-07-28 12:59:41 (176 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291663/DSC_0249_247633f5-55f7-4ce7-9f73-878c919b4104.jpg’ saved [6586977/6586977]
#
# --2022-07-28 12:59:41--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291669/DSC_0081_f8c983f9-2b3e-4924-b8ea-d4ef68961d83.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5673683 (5.4M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291669/DSC_0081_f8c983f9-2b3e-4924-b8ea-d4ef68961d83.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.41M  --.-KB/s    in 0.02s
#
# 2022-07-28 12:59:42 (349 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291669/DSC_0081_f8c983f9-2b3e-4924-b8ea-d4ef68961d83.jpg’ saved [5673683/5673683]
#
# --2022-07-28 12:59:42--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291518/DSC_1116_a494161a-11ce-49c8-9c64-23b6aa488266.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6309205 (6.0M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291518/DSC_1116_a494161a-11ce-49c8-9c64-23b6aa488266.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.02M  --.-KB/s    in 0.08s
#
# 2022-07-28 12:59:42 (76.6 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291518/DSC_1116_a494161a-11ce-49c8-9c64-23b6aa488266.jpg’ saved [6309205/6309205]
#
# --2022-07-28 12:59:42--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291551/DSC_3618_a4797516-c202-4415-a3ed-be218a2089f4.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6117062 (5.8M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291551/DSC_3618_a4797516-c202-4415-a3ed-be218a2089f4.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.83M  --.-KB/s    in 0.02s
#
# 2022-07-28 12:59:42 (280 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291551/DSC_3618_a4797516-c202-4415-a3ed-be218a2089f4.jpg’ saved [6117062/6117062]
#
# --2022-07-28 12:59:42--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291551/DSC_3876_4f0d8eaf-1978-4d86-9f7f-338c06c395cf.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6293348 (6.0M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291551/DSC_3876_4f0d8eaf-1978-4d86-9f7f-338c06c395cf.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.00M  --.-KB/s    in 0.03s
#
# 2022-07-28 12:59:42 (224 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291551/DSC_3876_4f0d8eaf-1978-4d86-9f7f-338c06c395cf.jpg’ saved [6293348/6293348]
#
# --2022-07-28 12:59:42--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291572/DSC_0001_37dcbcac-69a8-4f0a-bc20-b43f4c83e342.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3155903 (3.0M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291572/DSC_0001_37dcbcac-69a8-4f0a-bc20-b43f4c83e342.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   3.01M  --.-KB/s    in 0.06s
#
# 2022-07-28 12:59:42 (52.9 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291572/DSC_0001_37dcbcac-69a8-4f0a-bc20-b43f4c83e342.jpg’ saved [3155903/3155903]
#
# --2022-07-28 12:59:42--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291576/DSC_0567_0a58e74f-1226-47f9-86a3-7271daa23856.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5818732 (5.5M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291576/DSC_0567_0a58e74f-1226-47f9-86a3-7271daa23856.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.55M  --.-KB/s    in 0.02s
#
# 2022-07-28 12:59:42 (346 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291576/DSC_0567_0a58e74f-1226-47f9-86a3-7271daa23856.jpg’ saved [5818732/5818732]
#
# --2022-07-28 12:59:42--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/30315/DSC_2851_2f502d8e-9206-4f11-ad4f-9a5a6e76482f.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7547072 (7.2M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/30315/DSC_2851_2f502d8e-9206-4f11-ad4f-9a5a6e76482f.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   7.20M  --.-KB/s    in 0.03s
#
# 2022-07-28 12:59:42 (229 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/30315/DSC_2851_2f502d8e-9206-4f11-ad4f-9a5a6e76482f.jpg’ saved [7547072/7547072]
#
# --2022-07-28 12:59:42--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/614096/Powerpla_80d83241-85ce-461e-84e2-367682f3d6c9.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13088276 (12M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/614096/Powerpla_80d83241-85ce-461e-84e2-367682f3d6c9.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  12.48M  83.1MB/s    in 0.2s
#
# 2022-07-28 12:59:43 (83.1 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/614096/Powerpla_80d83241-85ce-461e-84e2-367682f3d6c9.jpg’ saved [13088276/13088276]
#
# --2022-07-28 12:59:43--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/614925/DSC_0034_20dda24d-eb6f-4ab2-bf67-a2310709038b.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6303402 (6.0M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/614925/DSC_0034_20dda24d-eb6f-4ab2-bf67-a2310709038b.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.01M  --.-KB/s    in 0.08s
#
# 2022-07-28 12:59:43 (74.7 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/614925/DSC_0034_20dda24d-eb6f-4ab2-bf67-a2310709038b.jpg’ saved [6303402/6303402]
#
# --2022-07-28 12:59:43--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/614945/DSC_1714_a3afcd64-49ed-40c4-818a-864646d986c2.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5840191 (5.6M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/614945/DSC_1714_a3afcd64-49ed-40c4-818a-864646d986c2.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.57M  --.-KB/s    in 0.02s
#
# 2022-07-28 12:59:43 (364 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/614945/DSC_1714_a3afcd64-49ed-40c4-818a-864646d986c2.jpg’ saved [5840191/5840191]
#
# --2022-07-28 12:59:43--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/615223/VIRB0169_c7e93933-f4e1-46f3-ac37-8ebc12c9a843.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3476077 (3.3M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/615223/VIRB0169_c7e93933-f4e1-46f3-ac37-8ebc12c9a843.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   3.31M  --.-KB/s    in 0.08s
#
# 2022-07-28 12:59:43 (42.2 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/615223/VIRB0169_c7e93933-f4e1-46f3-ac37-8ebc12c9a843.jpg’ saved [3476077/3476077]
#
# --2022-07-28 12:59:43--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/615483/DSC_1282_269655d0-69a2-4e63-999d-0cf84d5e84a9.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 14725375 (14M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/615483/DSC_1282_269655d0-69a2-4e63-999d-0cf84d5e84a9.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  14.04M  78.4MB/s    in 0.2s
#
# 2022-07-28 12:59:43 (78.4 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/615483/DSC_1282_269655d0-69a2-4e63-999d-0cf84d5e84a9.jpg’ saved [14725375/14725375]
#
# --2022-07-28 12:59:43--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/615754/19-T-467_d7f278c6-6cd4-465d-a710-584732a9245d.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10472756 (10.0M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/615754/19-T-467_d7f278c6-6cd4-465d-a710-584732a9245d.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   9.99M  --.-KB/s    in 0.08s
#
# 2022-07-28 12:59:44 (122 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/615754/19-T-467_d7f278c6-6cd4-465d-a710-584732a9245d.jpg’ saved [10472756/10472756]
#
# --2022-07-28 12:59:44--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/615862/DSC_8013_d6754944-32c8-45d5-a411-2a4c48f8bc08.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13819116 (13M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/615862/DSC_8013_d6754944-32c8-45d5-a411-2a4c48f8bc08.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  13.18M  48.4MB/s    in 0.3s
#
# 2022-07-28 12:59:44 (48.4 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/615862/DSC_8013_d6754944-32c8-45d5-a411-2a4c48f8bc08.jpg’ saved [13819116/13819116]
#
# --2022-07-28 12:59:44--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5055/382400/DSC_5165_2c85905c-1ca0-4c84-90b3-4e0730b143b8.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6136677 (5.9M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5055/382400/DSC_5165_2c85905c-1ca0-4c84-90b3-4e0730b143b8.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.85M  --.-KB/s    in 0.02s
#
# 2022-07-28 12:59:44 (263 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5055/382400/DSC_5165_2c85905c-1ca0-4c84-90b3-4e0730b143b8.jpg’ saved [6136677/6136677]
#
# --2022-07-28 12:59:44--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/7067/533485/DJI_0100_249049ee-a74b-4708-8fce-61c3bc9a9931.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7021024 (6.7M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/7067/533485/DJI_0100_249049ee-a74b-4708-8fce-61c3bc9a9931.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.70M  --.-KB/s    in 0.02s
#
# 2022-07-28 12:59:44 (279 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/7067/533485/DJI_0100_249049ee-a74b-4708-8fce-61c3bc9a9931.jpg’ saved [7021024/7021024]
#
# --2022-07-28 12:59:44--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/7068/615404/DSC_7730_51486e1b-5991-451d-9eeb-e75c7332f015.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10644641 (10M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/7068/615404/DSC_7730_51486e1b-5991-451d-9eeb-e75c7332f015.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  10.15M  52.5MB/s    in 0.2s
#
# 2022-07-28 12:59:44 (52.5 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/7068/615404/DSC_7730_51486e1b-5991-451d-9eeb-e75c7332f015.jpg’ saved [10644641/10644641]
#
# --2022-07-28 12:59:44--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613531/DSC_0700_154d47db-d88e-4326-984a-c39eb46b286a.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13503295 (13M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613531/DSC_0700_154d47db-d88e-4326-984a-c39eb46b286a.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  12.88M  --.-KB/s    in 0.1s
#
# 2022-07-28 12:59:45 (112 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613531/DSC_0700_154d47db-d88e-4326-984a-c39eb46b286a.jpg’ saved [13503295/13503295]
#
# --2022-07-28 12:59:45--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613531/DSC_0903_2ad66ee3-a161-4582-83f0-4442fa7333a0.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11669203 (11M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613531/DSC_0903_2ad66ee3-a161-4582-83f0-4442fa7333a0.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  11.13M  67.5MB/s    in 0.2s
#
# 2022-07-28 12:59:45 (67.5 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613531/DSC_0903_2ad66ee3-a161-4582-83f0-4442fa7333a0.jpg’ saved [11669203/11669203]
#
# --2022-07-28 12:59:45--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613538/DSC_0808_47aa2eb8-49b1-484b-8d6f-a4d31caf6cba.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 14246184 (14M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613538/DSC_0808_47aa2eb8-49b1-484b-8d6f-a4d31caf6cba.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  13.59M  84.2MB/s    in 0.2s
#
# 2022-07-28 12:59:45 (84.2 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613538/DSC_0808_47aa2eb8-49b1-484b-8d6f-a4d31caf6cba.jpg’ saved [14246184/14246184]
#
# --2022-07-28 12:59:45--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613538/DSC_1514_9900f945-ab93-4673-ae5c-810b525b2d34.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10942870 (10M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613538/DSC_1514_9900f945-ab93-4673-ae5c-810b525b2d34.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  10.44M  55.5MB/s    in 0.2s
#
# 2022-07-28 12:59:46 (55.5 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613538/DSC_1514_9900f945-ab93-4673-ae5c-810b525b2d34.jpg’ saved [10942870/10942870]
#
# --2022-07-28 12:59:46--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613542/DSC_0415_aee8b7ae-6dfc-4d0e-a8ca-fecf6abfd1ee.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 9879714 (9.4M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613542/DSC_0415_aee8b7ae-6dfc-4d0e-a8ca-fecf6abfd1ee.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   9.42M  --.-KB/s    in 0.09s
#
# 2022-07-28 12:59:46 (106 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613542/DSC_0415_aee8b7ae-6dfc-4d0e-a8ca-fecf6abfd1ee.jpg’ saved [9879714/9879714]
#
# --2022-07-28 12:59:46--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613543/DSC_0510_3df41677-499e-47d0-9d5d-b02b78493ec2.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11650226 (11M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613543/DSC_0510_3df41677-499e-47d0-9d5d-b02b78493ec2.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  11.11M  37.2MB/s    in 0.3s
#
# 2022-07-28 12:59:46 (37.2 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613543/DSC_0510_3df41677-499e-47d0-9d5d-b02b78493ec2.jpg’ saved [11650226/11650226]
#
# --2022-07-28 12:59:46--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613543/DSC_0839_c840a504-9b8c-4c59-afaa-86737f9860ae.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 12428012 (12M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613543/DSC_0839_c840a504-9b8c-4c59-afaa-86737f9860ae.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  11.85M  59.0MB/s    in 0.2s
#
# 2022-07-28 12:59:46 (59.0 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613543/DSC_0839_c840a504-9b8c-4c59-afaa-86737f9860ae.jpg’ saved [12428012/12428012]
#
# --2022-07-28 12:59:46--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613546/DSC_0326_08586a4e-4ae0-4aa5-b1c9-4cde121a0b6f.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 8873062 (8.5M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613546/DSC_0326_08586a4e-4ae0-4aa5-b1c9-4cde121a0b6f.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   8.46M  --.-KB/s    in 0.06s
#
# 2022-07-28 12:59:47 (148 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613546/DSC_0326_08586a4e-4ae0-4aa5-b1c9-4cde121a0b6f.jpg’ saved [8873062/8873062]
#
# --2022-07-28 12:59:47--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613547/DSC_1617_7c51340a-1db6-41c1-8d40-d503018543fc.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7826607 (7.5M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613547/DSC_1617_7c51340a-1db6-41c1-8d40-d503018543fc.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   7.46M  --.-KB/s    in 0.05s
#
# 2022-07-28 12:59:47 (141 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613547/DSC_1617_7c51340a-1db6-41c1-8d40-d503018543fc.jpg’ saved [7826607/7826607]
#
# --2022-07-28 12:59:47--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613548/DSC_1963_4e6e1abc-131d-4a48-adf6-aa93ec41c6ed.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10313967 (9.8M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613548/DSC_1963_4e6e1abc-131d-4a48-adf6-aa93ec41c6ed.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   9.84M  --.-KB/s    in 0.08s
#
# 2022-07-28 12:59:47 (119 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613548/DSC_1963_4e6e1abc-131d-4a48-adf6-aa93ec41c6ed.jpg’ saved [10313967/10313967]
#
# --2022-07-28 12:59:47--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613548/DSC_2033_5e768648-fd72-4a2a-b598-adfe38b06f26.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 9507678 (9.1M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613548/DSC_2033_5e768648-fd72-4a2a-b598-adfe38b06f26.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   9.07M  --.-KB/s    in 0.1s
#
# 2022-07-28 12:59:47 (90.6 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613548/DSC_2033_5e768648-fd72-4a2a-b598-adfe38b06f26.jpg’ saved [9507678/9507678]
#
# --2022-07-28 12:59:47--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613548/DSC_2464_50f99d3d-2d50-4aba-8e26-7ba84293b5ed.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 8653982 (8.3M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613548/DSC_2464_50f99d3d-2d50-4aba-8e26-7ba84293b5ed.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   8.25M  --.-KB/s    in 0.1s
#
# 2022-07-28 12:59:47 (77.8 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613548/DSC_2464_50f99d3d-2d50-4aba-8e26-7ba84293b5ed.jpg’ saved [8653982/8653982]
#
# --2022-07-28 12:59:47--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613550/DSC_1213_06f39bad-055f-4495-aa81-4d24c5894cbd.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10056085 (9.6M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613550/DSC_1213_06f39bad-055f-4495-aa81-4d24c5894cbd.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   9.59M  --.-KB/s    in 0.08s
#
# 2022-07-28 12:59:47 (119 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613550/DSC_1213_06f39bad-055f-4495-aa81-4d24c5894cbd.jpg’ saved [10056085/10056085]
#
# --2022-07-28 12:59:47--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613551/DSC_0011_352db129-53e3-4250-8c91-ea04dbd56723.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11661277 (11M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613551/DSC_0011_352db129-53e3-4250-8c91-ea04dbd56723.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  11.12M  33.9MB/s    in 0.3s
#
# 2022-07-28 12:59:48 (33.9 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613551/DSC_0011_352db129-53e3-4250-8c91-ea04dbd56723.jpg’ saved [11661277/11661277]
#
# --2022-07-28 12:59:48--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613551/DSC_0743_775cb945-002f-4262-80d0-b1a9aae828d1.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10876281 (10M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613551/DSC_0743_775cb945-002f-4262-80d0-b1a9aae828d1.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  10.37M  55.8MB/s    in 0.2s
#
# 2022-07-28 12:59:48 (55.8 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613551/DSC_0743_775cb945-002f-4262-80d0-b1a9aae828d1.jpg’ saved [10876281/10876281]
#
# --2022-07-28 12:59:48--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613555/DSC_0061_6a7bfd4b-725f-4713-a6bf-b7a0aa064f7a.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13767934 (13M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613555/DSC_0061_6a7bfd4b-725f-4713-a6bf-b7a0aa064f7a.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  13.13M  60.8MB/s    in 0.2s
#
# 2022-07-28 12:59:48 (60.8 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613555/DSC_0061_6a7bfd4b-725f-4713-a6bf-b7a0aa064f7a.jpg’ saved [13767934/13767934]
#
# --2022-07-28 12:59:48--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613555/DSC_0511_00d80666-efee-4d8f-8e18-9ef3a8b45dee.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10303755 (9.8M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613555/DSC_0511_00d80666-efee-4d8f-8e18-9ef3a8b45dee.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   9.83M  --.-KB/s    in 0.1s
#
# 2022-07-28 12:59:49 (79.8 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613555/DSC_0511_00d80666-efee-4d8f-8e18-9ef3a8b45dee.jpg’ saved [10303755/10303755]
#
# --2022-07-28 12:59:49--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613555/DSC_0913_7ccdbf08-9b69-4921-9da0-270dc2e959ed.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11451720 (11M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613555/DSC_0913_7ccdbf08-9b69-4921-9da0-270dc2e959ed.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  10.92M  60.0MB/s    in 0.2s
#
# 2022-07-28 12:59:49 (60.0 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613555/DSC_0913_7ccdbf08-9b69-4921-9da0-270dc2e959ed.jpg’ saved [11451720/11451720]
#
# --2022-07-28 12:59:49--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613556/DSC_0392_4f07bf12-de3d-42fe-bba4-779ad0b7a8eb.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11039136 (11M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613556/DSC_0392_4f07bf12-de3d-42fe-bba4-779ad0b7a8eb.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  10.53M  38.9MB/s    in 0.3s
#
# 2022-07-28 12:59:49 (38.9 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613556/DSC_0392_4f07bf12-de3d-42fe-bba4-779ad0b7a8eb.jpg’ saved [11039136/11039136]
#
# --2022-07-28 12:59:49--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613556/DSC_1134_3c25523f-04cc-45ec-ac62-a184663d1ed1.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 9400278 (9.0M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613556/DSC_1134_3c25523f-04cc-45ec-ac62-a184663d1ed1.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   8.96M  --.-KB/s    in 0.08s
#
# 2022-07-28 12:59:50 (111 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613556/DSC_1134_3c25523f-04cc-45ec-ac62-a184663d1ed1.jpg’ saved [9400278/9400278]
#
# --2022-07-28 12:59:50--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613574/A67_0050_231d3180-a136-4ba7-80dc-32eff6812857.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 12684454 (12M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613574/A67_0050_231d3180-a136-4ba7-80dc-32eff6812857.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  12.10M  --.-KB/s    in 0.1s
#
# 2022-07-28 12:59:50 (85.2 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613574/A67_0050_231d3180-a136-4ba7-80dc-32eff6812857.jpg’ saved [12684454/12684454]
#
# --2022-07-28 12:59:50--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613574/A67_0363_443ded28-1ccd-45c0-a898-47c45225c7db.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10714416 (10M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613574/A67_0363_443ded28-1ccd-45c0-a898-47c45225c7db.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  10.22M  50.8MB/s    in 0.2s
#
# 2022-07-28 12:59:50 (50.8 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613574/A67_0363_443ded28-1ccd-45c0-a898-47c45225c7db.jpg’ saved [10714416/10714416]
#
# --2022-07-28 12:59:50--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613577/DSC_0891_8de6dfd8-8bdc-493e-9406-2d391867e60a.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7207610 (6.9M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613577/DSC_0891_8de6dfd8-8bdc-493e-9406-2d391867e60a.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.87M  --.-KB/s    in 0.03s
#
# 2022-07-28 12:59:50 (204 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613577/DSC_0891_8de6dfd8-8bdc-493e-9406-2d391867e60a.jpg’ saved [7207610/7207610]
#
# --2022-07-28 12:59:50--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613577/DSC_1125_8684121f-be5f-4513-805e-7b80cbd4729e.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4765525 (4.5M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613577/DSC_1125_8684121f-be5f-4513-805e-7b80cbd4729e.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   4.54M  --.-KB/s    in 0.07s
#
# 2022-07-28 12:59:50 (66.1 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613577/DSC_1125_8684121f-be5f-4513-805e-7b80cbd4729e.jpg’ saved [4765525/4765525]
#
# --2022-07-28 12:59:50--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613586/DSC_0931_06649e36-c768-4416-b809-a5d185563f77.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11497216 (11M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613586/DSC_0931_06649e36-c768-4416-b809-a5d185563f77.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  10.96M  66.7MB/s    in 0.2s
#
# 2022-07-28 12:59:51 (66.7 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613586/DSC_0931_06649e36-c768-4416-b809-a5d185563f77.jpg’ saved [11497216/11497216]
#
# --2022-07-28 12:59:51--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613586/DSC_1462_56b443dd-b1bf-4acb-9acb-9440ad832fbc.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 8976804 (8.6M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613586/DSC_1462_56b443dd-b1bf-4acb-9acb-9440ad832fbc.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   8.56M  --.-KB/s    in 0.08s
#
# 2022-07-28 12:59:51 (110 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613586/DSC_1462_56b443dd-b1bf-4acb-9acb-9440ad832fbc.jpg’ saved [8976804/8976804]
#
# --2022-07-28 12:59:51--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613645/DSC_0248_7dbdd099-48d7-4463-8a11-beb68acb51ed.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 9114583 (8.7M) [image/jpeg]
# ...
# HTTP request sent, awaiting response... 200 OK
# Length: 6071400 (5.8M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615127/TimCooli_5c443c14-d2cc-466b-a6d4-a749359d0f20.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.79M  --.-KB/s    in 0.02s
#
# 2022-07-28 13:00:56 (265 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615127/TimCooli_5c443c14-d2cc-466b-a6d4-a749359d0f20.jpg’ saved [6071400/6071400]
#
# --2022-07-28 13:00:56--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615129/BrettGro_4532a2e2-0966-4a65-bdab-b1b5f01f6830.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3461646 (3.3M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615129/BrettGro_4532a2e2-0966-4a65-bdab-b1b5f01f6830.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   3.30M  --.-KB/s    in 0.1s
#
# 2022-07-28 13:00:56 (24.2 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615129/BrettGro_4532a2e2-0966-4a65-bdab-b1b5f01f6830.jpg’ saved [3461646/3461646]
#
# --2022-07-28 13:00:56--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615129/BrettGro_beea0605-e188-4808-af65-587f23409494.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3460191 (3.3M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615129/BrettGro_beea0605-e188-4808-af65-587f23409494.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   3.30M  --.-KB/s    in 0.01s
#
# 2022-07-28 13:00:56 (267 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615129/BrettGro_beea0605-e188-4808-af65-587f23409494.jpg’ saved [3460191/3460191]
#
# --2022-07-28 13:00:56--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615138/DSC_7298_fb6ed43d-57ee-496e-b38d-65b98a5d8a14.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6202127 (5.9M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615138/DSC_7298_fb6ed43d-57ee-496e-b38d-65b98a5d8a14.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.91M  --.-KB/s    in 0.05s
#
# 2022-07-28 13:00:56 (115 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615138/DSC_7298_fb6ed43d-57ee-496e-b38d-65b98a5d8a14.jpg’ saved [6202127/6202127]
#
# --2022-07-28 13:00:56--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615149/19-1-352_fea2d7df-4964-4a76-bc3e-58e9f4e33961.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 8433249 (8.0M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615149/19-1-352_fea2d7df-4964-4a76-bc3e-58e9f4e33961.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   8.04M  --.-KB/s    in 0.1s
#
# 2022-07-28 13:00:56 (69.4 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615149/19-1-352_fea2d7df-4964-4a76-bc3e-58e9f4e33961.jpg’ saved [8433249/8433249]
#
# --2022-07-28 13:00:56--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615183/DSC_2219_ab9f1d19-1597-402e-8dac-f64f91a72a7a.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 12476311 (12M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615183/DSC_2219_ab9f1d19-1597-402e-8dac-f64f91a72a7a.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  11.90M  51.6MB/s    in 0.2s
#
# 2022-07-28 13:00:57 (51.6 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615183/DSC_2219_ab9f1d19-1597-402e-8dac-f64f91a72a7a.jpg’ saved [12476311/12476311]
#
# --2022-07-28 13:00:57--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615185/DSC_4271_eccb7fa5-fcab-4831-b054-89c6492fc265.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7666520 (7.3M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615185/DSC_4271_eccb7fa5-fcab-4831-b054-89c6492fc265.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   7.31M  --.-KB/s    in 0.03s
#
# 2022-07-28 13:00:57 (238 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615185/DSC_4271_eccb7fa5-fcab-4831-b054-89c6492fc265.jpg’ saved [7666520/7666520]
#
# --2022-07-28 13:00:57--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615192/-193_d3638b4f-21cc-4def-93a8-9b89c8dc14e5.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13596828 (13M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615192/-193_d3638b4f-21cc-4def-93a8-9b89c8dc14e5.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  12.97M  56.2MB/s    in 0.2s
#
# 2022-07-28 13:00:57 (56.2 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615192/-193_d3638b4f-21cc-4def-93a8-9b89c8dc14e5.jpg’ saved [13596828/13596828]
#
# --2022-07-28 13:00:57--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615210/DSC_3708_e3d4a77b-dce1-48c3-96df-4b6827385e7a.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 8827082 (8.4M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615210/DSC_3708_e3d4a77b-dce1-48c3-96df-4b6827385e7a.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   8.42M  35.2MB/s    in 0.2s
#
# 2022-07-28 13:00:58 (35.2 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615210/DSC_3708_e3d4a77b-dce1-48c3-96df-4b6827385e7a.jpg’ saved [8827082/8827082]
#
# --2022-07-28 13:00:58--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615216/DSC_0243_59d8230a-42dd-49ad-aa6a-afa583602f33.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3077648 (2.9M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615216/DSC_0243_59d8230a-42dd-49ad-aa6a-afa583602f33.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   2.93M  --.-KB/s    in 0.04s
#
# 2022-07-28 13:00:58 (82.1 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615216/DSC_0243_59d8230a-42dd-49ad-aa6a-afa583602f33.jpg’ saved [3077648/3077648]
#
# --2022-07-28 13:00:58--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615224/Bay-Gulf_88eea661-1437-4656-a2e3-410c4604ab06.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13939271 (13M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615224/Bay-Gulf_88eea661-1437-4656-a2e3-410c4604ab06.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  13.29M  70.6MB/s    in 0.2s
#
# 2022-07-28 13:00:58 (70.6 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615224/Bay-Gulf_88eea661-1437-4656-a2e3-410c4604ab06.jpg’ saved [13939271/13939271]
#
# --2022-07-28 13:00:58--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615225/DSC_0025_113566da-58e4-4431-a321-c01aa02c8df9.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7136860 (6.8M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615225/DSC_0025_113566da-58e4-4431-a321-c01aa02c8df9.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.81M  --.-KB/s    in 0.08s
#
# 2022-07-28 13:00:58 (88.2 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615225/DSC_0025_113566da-58e4-4431-a321-c01aa02c8df9.jpg’ saved [7136860/7136860]
#
# --2022-07-28 13:00:58--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615225/DSC_0133_461855cd-a623-4a29-925b-e5fba39e7aff.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5451414 (5.2M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615225/DSC_0133_461855cd-a623-4a29-925b-e5fba39e7aff.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.20M  --.-KB/s    in 0.1s
#
# 2022-07-28 13:00:58 (51.1 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615225/DSC_0133_461855cd-a623-4a29-925b-e5fba39e7aff.jpg’ saved [5451414/5451414]
#
# --2022-07-28 13:00:58--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615229/DSC_5158_aea0bb5c-2a66-4470-bbe2-55fd3bd34015.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13520843 (13M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615229/DSC_5158_aea0bb5c-2a66-4470-bbe2-55fd3bd34015.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  12.89M  57.3MB/s    in 0.2s
#
# 2022-07-28 13:00:59 (57.3 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615229/DSC_5158_aea0bb5c-2a66-4470-bbe2-55fd3bd34015.jpg’ saved [13520843/13520843]
#
# --2022-07-28 13:00:59--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615233/Bay-Gulf_07bcbfbc-7fa3-44cc-bf0b-27a2fbab9d04.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 15368946 (15M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615233/Bay-Gulf_07bcbfbc-7fa3-44cc-bf0b-27a2fbab9d04.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  14.66M  46.1MB/s    in 0.3s
#
# 2022-07-28 13:00:59 (46.1 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615233/Bay-Gulf_07bcbfbc-7fa3-44cc-bf0b-27a2fbab9d04.jpg’ saved [15368946/15368946]
#
# --2022-07-28 13:00:59--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615233/Bay-Gulf_c6507bcf-909d-4ee8-84fe-800a4ff8845f.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 14245222 (14M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615233/Bay-Gulf_c6507bcf-909d-4ee8-84fe-800a4ff8845f.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  13.58M  58.1MB/s    in 0.2s
#
# 2022-07-28 13:00:59 (58.1 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615233/Bay-Gulf_c6507bcf-909d-4ee8-84fe-800a4ff8845f.jpg’ saved [14245222/14245222]
#
# --2022-07-28 13:00:59--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615236/DSC_5942_d8153bc5-3342-4e82-af8e-2b51ff59dfa6.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13588573 (13M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615236/DSC_5942_d8153bc5-3342-4e82-af8e-2b51ff59dfa6.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  12.96M  53.1MB/s    in 0.2s
#
# 2022-07-28 13:01:00 (53.1 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615236/DSC_5942_d8153bc5-3342-4e82-af8e-2b51ff59dfa6.jpg’ saved [13588573/13588573]
#
# --2022-07-28 13:01:00--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615237/DSC_6136_91f6f837-aadf-433f-8139-af808be95f3e.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 14592908 (14M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615237/DSC_6136_91f6f837-aadf-433f-8139-af808be95f3e.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  13.92M  62.0MB/s    in 0.2s
#
# 2022-07-28 13:01:00 (62.0 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615237/DSC_6136_91f6f837-aadf-433f-8139-af808be95f3e.jpg’ saved [14592908/14592908]
#
# --2022-07-28 13:01:00--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9107/616211/DSC_1285_d22ed553-8513-4483-932f-27c07303df75.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 16000161 (15M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9107/616211/DSC_1285_d22ed553-8513-4483-932f-27c07303df75.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  15.26M  45.1MB/s    in 0.3s
#
# 2022-07-28 13:01:01 (45.1 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9107/616211/DSC_1285_d22ed553-8513-4483-932f-27c07303df75.jpg’ saved [16000161/16000161]
#
# --2022-07-28 13:01:01--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_8119_223855cd-7e91-4d2f-8ed6-9225bb1254d1.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11499088 (11M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_8119_223855cd-7e91-4d2f-8ed6-9225bb1254d1.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  10.97M  54.9MB/s    in 0.2s
#
# 2022-07-28 13:01:01 (54.9 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_8119_223855cd-7e91-4d2f-8ed6-9225bb1254d1.jpg’ saved [11499088/11499088]
#
# --2022-07-28 13:01:01--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_8237_3b20c33b-6357-4547-ab17-153a4e7e4737.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 14907837 (14M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_8237_3b20c33b-6357-4547-ab17-153a4e7e4737.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  14.22M  34.3MB/s    in 0.4s
#
# 2022-07-28 13:01:01 (34.3 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_8237_3b20c33b-6357-4547-ab17-153a4e7e4737.jpg’ saved [14907837/14907837]
#
# --2022-07-28 13:01:01--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9161/616221/FEMA_REG_91283628-d9b0-48ac-8f39-c485597c3021.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5074359 (4.8M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9161/616221/FEMA_REG_91283628-d9b0-48ac-8f39-c485597c3021.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   4.84M  --.-KB/s    in 0.02s
#
# 2022-07-28 13:01:02 (261 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9161/616221/FEMA_REG_91283628-d9b0-48ac-8f39-c485597c3021.jpg’ saved [5074359/5074359]
#
# --2022-07-28 13:01:02--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9161/616221/FEMA_REG_db388a8e-36a3-4e5d-bfa8-68582ba489ab.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4851339 (4.6M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9161/616221/FEMA_REG_db388a8e-36a3-4e5d-bfa8-68582ba489ab.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   4.63M  --.-KB/s    in 0.05s
#
# 2022-07-28 13:01:02 (99.6 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9161/616221/FEMA_REG_db388a8e-36a3-4e5d-bfa8-68582ba489ab.jpg’ saved [4851339/4851339]
#
# --2022-07-28 13:01:02--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9161/616227/FEMA_Reg_a4099275-d4b7-41bb-9109-edc3440ed3c4.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 9283395 (8.9M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9161/616227/FEMA_Reg_a4099275-d4b7-41bb-9109-edc3440ed3c4.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   8.85M  --.-KB/s    in 0.1s
#
# 2022-07-28 13:01:02 (67.7 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9161/616227/FEMA_Reg_a4099275-d4b7-41bb-9109-edc3440ed3c4.jpg’ saved [9283395/9283395]
#
# FINISHED --2022-07-28 13:01:02--
# Total wall clock time: 1m 26s
# Downloaded: 397 files, 3.2G in 43s (74.3 MB/s)

# %% [markdown]
# ### Exercise
# Take a look at the LADI csv files. Find some classification task that you find meaningful (e.g. detecting a bridge in an image). Create a csv file like the ones above for the metadata and the label. You might have to do some additional steps in data cleaning, depending on your choice
